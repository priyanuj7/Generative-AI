# %%
# !pip install pymupdf

# %%
import fitz # for PyMuPDF
from langchain_core.documents import Document
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import torch
import numpy as np
from langchain.chat_models import init_chat_model
from langchain.prompts import PromptTemplate
from langchain.schema.messages import HumanMessage
from sklearn.metrics.pairwise import cosine_similarity
import os
import base64
import io
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS

# %%
from google.colab import userdata

# Load the API key from Colab secrets
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
# Initialize Clip Model for unified Embeddings

clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
clip_model.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# CLIPModel(
#   (text_model): CLIPTextTransformer(
#     (embeddings): CLIPTextEmbeddings(
#       (token_embedding): Embedding(49408, 512)
#       (position_embedding): Embedding(77, 512)
#     )
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (layer_norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#           (layer_norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (vision_model): CLIPVisionTransformer(
#     (embeddings): CLIPVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#       (position_embedding): Embedding(50, 768)
#     )
#     (pre_layrnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (visual_projection): Linear(in_features=768, out_features=512, bias=False)
#   (text_projection): Linear(in_features=512, out_features=512, bias=False)
# )

# %%
def embed_image(image_data):
  """Embed image using CLIP"""
  if isinstance(image_data, str): #path
    image = Image.open(image_data).convert("RGB")
  else:
    image = image_data

  inputs = clip_processor(images=image, return_tensors="pt")
  with torch.no_grad():
    features = clip_model.get_image_features(**inputs)
    features = features / features.norm(dim=-1, keepdim = True)
  return features.squeeze().numpy()


def embed_text(text):
  """Embed text using CLIP"""
  inputs = clip_processor(text=text, return_tensors="pt", padding = True, truncation = True, max_length = 77)
  with torch.no_grad():
    features = clip_model.get_text_features(**inputs)
    features = features / features.norm(dim = -1, keepdim = True)
    return features.squeeze().numpy()

# %%
from google.colab import drive
drive.mount('/content/drive')

pdf_path = '/content/drive/My Drive/Multimodal_RAG/LectureNotesCNN.pdf'


doc = fitz.open(pdf_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
doc
# Out:
# Document('/content/drive/My Drive/Multimodal_RAG/LectureNotesCNN.pdf')

# %%
all_docs = []
all_embeddings = []
image_data_store = {}

splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 100)

# %%
for i, page in enumerate(doc):
  #process text
  text = page.get_text()
  if text.strip():
    #create temporary document for splitting
    temp_doc = Document(page_content = text, metadata = {"page": f"{i}", "type": "text"})
    text_chunks = splitter.split_documents([temp_doc])

    for chunk in text_chunks:
      embedding = embed_text(chunk.page_content)
      all_embeddings.append(embedding)
      all_docs.append(chunk)

  #Process images
  for img_index, img in enumerate(page.get_images(full=True)):
    try:
        xref = img[0]
        base_image = doc.extract_image(xref)
        image_bytes = base_image["image"]

        # Convert to PIL Image
        pil_image = Image.open(io.BytesIO(image_bytes)).convert("RGB")

        # Create unique identifier
        image_id = f"page_{i}_img_{img_index}"

        # Store image as base64 for later use with GPT-4V
        buffered = io.BytesIO()
        pil_image.save(buffered, format="PNG")
        img_base64 = base64.b64encode(buffered.getvalue()).decode()
        image_data_store[image_id] = img_base64

        # Embed image using CLIP
        embedding = embed_image(pil_image)
        all_embeddings.append(embedding)

        # Create document for image
        image_doc = Document(
            page_content=f"[Image: {image_id}]",
            metadata={"page": i, "type": "image", "image_id": image_id}
        )
        all_docs.append(image_doc)

    except Exception as e:
        print(f"Error processing image {img_index} on page {i}: {e}")
        continue

doc.close()
# Out:
# The channel dimension is ambiguous. Got image shape (1, 1, 3). Assuming channels are the first dimension. Use the [input_data_format](https://huggingface.co/docs/transformers/main/internal/image_processing_utils#transformers.image_transforms.rescale.input_data_format) parameter to assign the channel dimension.
# Error processing image 2 on page 9: mean must have 1 elements if it is an iterable, got 3

# %%
all_embeddings
# Out:
# [array([ 4.28104661e-02,  4.59232507e-03, -2.15550233e-03, -1.03625329e-02,
#         -3.96510437e-02,  7.29156454e-05,  4.31593321e-02,  2.26110090e-02,
#          1.10872686e-01,  1.04269516e-02, -7.16207223e-03,  2.07392555e-02,
#          5.42129064e-03, -2.97503453e-03,  2.58059651e-02, -5.18025123e-02,
#          1.83949322e-02,  7.27241337e-02, -8.78350437e-03,  9.69066191e-03,
#          3.12640145e-02,  4.73436601e-02, -5.70419105e-03,  2.84244847e-02,
#         -1.02167092e-02,  6.02104217e-02,  2.04029679e-02,  6.55344874e-03,
#         -8.03259667e-03,  1.36123877e-02,  1.46810163e-03, -2.52798982e-02,
#          1.72378235e-02, -2.76862923e-02, -2.81521678e-02,  2.16138270e-02,
#         -1.25964750e-02, -4.99115558e-03, -2.40088850e-02,  5.94377927e-02,
#         -1.20263686e-02, -8.79801251e-03, -2.01767106e-02,  3.72255454e-03,
#          3.34920399e-02, -2.34949272e-02,  5.74917952e-03, -1.60801504e-02,
#          1.09162368e-02,  2.29487643e-02,  3.11948955e-02,  9.51208174e-03,
#          1.10451607e-02, -3.47620323e-02, -2.04389971e-02,  4.35831957e-02,
#         -2.30260706e-03,  1.17567426e-03, -5.58230048e-03,  1.77869126e-02,
#          4.31595109e-02, -8.56104773e-03,  3.74240391e-02,  5.38579263e-02,
#          2.68401671e-02, -3.64053287e-02,  3.31173241e-02, -3.33048888e-02,
#         -1.43592656e-02, -5.56030031e-03, -3.44651267e-02, -1.38130076e-02,
#         -2.31829807e-02, -2.11640280e-02, -4.67883646e-02,  9.08725522e-03,
#         -1.45978704e-02,  2.06285920e-02, -4.31665070e-02, -2.85235792e-02,
#         -1.45440241e-02, -1.12066846e-02, -3.93314511e-02,  2.21449453e-02,
#          2.32655946e-02,  3.08887120e-02, -1.67388599e-02,  2.65465286e-02,
#         -3.66689973e-02,  3.85101140e-02, -3.51770483e-02, -9.64724738e-03],
#        dtype=float32)]

# %%
len(all_docs)
# Out:
# 81

# %%
embedding_array = np.array(all_embeddings)

vector_store = FAISS.from_embeddings(
    text_embeddings = [(doc.page_content, emb) for doc, emb in zip(all_docs, embedding_array)],
    embedding = None,
    metadatas = [doc.metadata for doc in all_docs]
)

vector_store
# Out:
# WARNING:langchain_community.vectorstores.faiss:`embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
llm = init_chat_model("openai:gpt-4.1")
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x7fce56d19810>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7fcde90ac8d0>, root_client=<openai.OpenAI object at 0x7fce56d18fd0>, root_async_client=<openai.AsyncOpenAI object at 0x7fcde90ac450>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'))

# %%
def retrieve_multimodal(query, k = 5):
  query_embedding = embed_text(query)

  results = vector_store.similarity_search_by_vector(
      embedding = query_embedding,
      k = k
  )
  return results

# %%
def create_multimodal_message(query, retrieved_docs):
    """Create a message with both text and images for GPT-4V."""
    content = []

    # Add the query
    content.append({
        "type": "text",
        "text": f"Question: {query}\n\nContext:\n"
    })

    # Separate text and image documents
    text_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "text"]
    image_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "image"]

    # Add text context
    if text_docs:
        text_context = "\n\n".join([
            f"[Page {doc.metadata['page']}]: {doc.page_content}"
            for doc in text_docs
        ])
        content.append({
            "type": "text",
            "text": f"Text excerpts:\n{text_context}\n"
        })

    # Add images
    for doc in image_docs:
        image_id = doc.metadata.get("image_id")
        if image_id and image_id in image_data_store:
            content.append({
                "type": "text",
                "text": f"\n[Image from page {doc.metadata['page']}]:\n"
            })
            content.append({
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/png;base64,{image_data_store[image_id]}"
                }
            })

    # Add instruction
    content.append({
        "type": "text",
        "text": "\n\nPlease answer the question based on the provided text and images."
    })

    return HumanMessage(content=content)

# %%
def multimodal_pdf_rag_pipeline(query):
    """Main pipeline for multimodal RAG."""
    # Retrieve relevant documents
    context_docs = retrieve_multimodal(query, k=5)

    # Create multimodal message
    message = create_multimodal_message(query, context_docs)

    # Get response from GPT-4V
    response = llm.invoke([message])

    # Print retrieved context info
    print(f"\nRetrieved {len(context_docs)} documents:")
    for doc in context_docs:
        doc_type = doc.metadata.get("type", "unknown")
        page = doc.metadata.get("page", "?")
        if doc_type == "text":
            preview = doc.page_content[:100] + "..." if len(doc.page_content) > 100 else doc.page_content
            print(f"  - Text from page {page}: {preview}")
        else:
            print(f"  - Image from page {page}")
    print("\n")

    return response.content

# %%
if __name__ == "__main__":
    # Example queries
    queries = [
        "What does the chart on page 1 show about what it says about CNN?",
        "Summarize the main findings from the document",
        "What visual elements are present in the document?"
    ]

    for query in queries:
        print(f"\nQuery: {query}")
        print("-" * 50)
        answer = multimodal_pdf_rag_pipeline(query)
        print(f"Answer: {answer}")
        print("=" * 70)
# Out:
# Query: What does the chart on page 1 show about what it says about CNN?
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 15: dataset is large, then you can fine-tune the model as you have enough data and need not to worry
# ab...
#   - Text from page 7: product of wT and p. The dot product is computed at every patch to get a (3, 3) output array, as sho...
#   - Text from page 15: So far, we have discussed CNN based networks which were trained on millions of images of various cla...
#   - Text from page 14: might be unsurprising) and then degrades rapidly. Unexpectedly, such degradation is not caused by
# o...
#   - Text from page 0: CNNs - A Specialised Architecture for Visual Data
#
#
#
#
# Convolutional Neural Networks, or CNNs, a...
#
#
# Answer: Based on the provided context, particularly the text from **page 1** (actually page 0 in your excerpts), here’s what the chart on that page shows about CNNs (Convolutional Neural Networks):
#
# **Key points from the context:**
#
# - CNNs are **specialized architectures for visual data** (images and videos).
# - They have been **responsible for revolutionizing deep learning**, especially in image processing tasks that used to be considered very difficult.
# - CNNs **set new benchmarks** on such tasks.
# - CNNs first demonstrated their **extraordinary performance in the ImageNet Large Scale Visual Recognition Challenge (ILSVRC)**, which uses about 1000 categories and 1.2 million images.
# - Compared to vanilla neural networks (like MLPs), CNNs are architecturally better suited for images, as MLPs don't exploit the structure in visual data.
#
# **What the chart likely shows:**
#
# While you haven’t provided the actual image/chart itself, based on this context, the chart on page 1 most likely **demonstrates the superiority or rapid improvement of CNNs on standard visual recognition benchmarks** (probably ILSVRC/ImageNet) compared to previous methods. This could be a performance-over-time chart, a comparison of error rates, or a visual representation of the jump in accuracy when CNNs were introduced.
#
# **What it says about CNN:**
#
# - **CNNs dramatically improved performance** on image recognition benchmarks (e.g., ImageNet).
# - Their architecture, tailored for images, enabled breakthroughs that flat/recurrent networks like MLPs could not achieve.
# - CNNs set a **new state-of-the-art for visual tasks**, and their impact on deep learning in vision is immediately clear from benchmark results.
#
# **Summary Table:**
#
# | What the Chart Shows                     | What it Says About CNN |
# |------------------------------------------|-----------------------|
# | CNNs outperform previous models on image benchmark tasks (like ILSVRC/ImageNet) | CNNs are fundamentally better at handling visual data, enable new levels of performance, and have revolutionized image recognition tasks |
#
# **In conclusion:**
# **The chart on page 1 visually shows the major leap in accuracy and performance on image benchmarks when CNNs were introduced, highlighting their revolutionary impact in computer vision as compared to previous neural network architectures.**
# ======================================================================
#
# Query: Summarize the main findings from the document
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 15: dataset is large, then you can fine-tune the model as you have enough data and need not to worry
# ab...
#   - Text from page 14: might be unsurprising) and then degrades rapidly. Unexpectedly, such degradation is not caused by
# o...
#   - Text from page 15: So far, we have discussed CNN based networks which were trained on millions of images of various cla...
#   - Text from page 6: convolution. Also, it helps to preserve the information at the borders. There are also alternate way...
#   - Text from page 13: Figure 16: 3x3 and 5x5 kernel
#
#
#
#
# GoogleNet stacks multiple filter along with 1x1 filter and po...
#
#
# Answer: **Summary of Main Findings:**
#
# 1. **ResNet and Deep Network Optimization:**
#    - **Skip Connections:** The introduction of skip connections in ResNet architectures allows very deep networks to be efficiently trained. Unlike traditional deep networks, which may suffer from degraded training accuracy as layers increase (not due to overfitting, but optimization difficulties), ResNet’s skip connections help maintain or even improve performance with increased depth.
#    - **Key Insight:** Adding more layers in a properly designed ResNet should not decrease accuracy due to the residual learning structure.
#
# 2. **CNNs as Feature Extractors and Transfer Learning:**
#    - **Feature Learning:** Convolutional Neural Networks (CNNs) trained on large datasets like ImageNet (1.2 million images across 1000 classes) learn feature representations that are broadly useful, not just for the original dataset or classification tasks.
#    - **Pre-trained Models:** In practice, most users do not train entire CNNs from scratch due to data limitations. Instead, pre-trained networks are commonly adapted to new tasks via transfer learning.
#    - **Transfer Learning Approaches:** There are two main strategies for adapting pre-trained models:
#      - **Freezing Initial Layers:** Use the weights learned from large datasets in initial layers (general features), replace and train only the last layers for the new task.
#      - **Fine-tuning:** If sufficient target data is available, some or all layers of the pre-trained model can be further trained (fine-tuned), with flexibility to fine-tune only later layers if overfitting is a concern.
#
# 3. **GoogleNet and Inception Modules:**
#    - **Inception Blocks:** GoogleNet leverages the Inception module, which stacks multiple types of filters (including 1x1, 3x3, and 5x5 convolutions, plus pooling) in parallel within the same block, enhancing feature extraction capabilities at varied scales.
#
# 4. **Convolution Details:**
#    - **Edge Handling:** Techniques like zero-padding (adding zeros around the image border) help to maintain information at image edges during convolution.
#
# **In summary:**
# Recent CNN architectures (like ResNet and GoogleNet) use innovative design features (skip connections and inception modules) to overcome challenges in training deep networks and extracting multi-scale features. CNNs trained on large datasets serve as powerful feature extractors, and transfer learning—by freezing or fine-tuning layers—enables effective use of these models for new tasks even with limited data. Zero-padding and filter stacking are important technical aspects enhancing these networks’ performance.
# ======================================================================
#
# Query: What visual elements are present in the document?
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 15: dataset is large, then you can fine-tune the model as you have enough data and need not to worry
# ab...
#   - Text from page 6: convolution. Also, it helps to preserve the information at the borders. There are also alternate way...
#   - Text from page 15: So far, we have discussed CNN based networks which were trained on millions of images of various cla...
#   - Text from page 5: Figure 9: Convolution in Depth
#
#
#
# Input, Filter and Output Dimension?
# In convolution, the numb...
#   - Text from page 14: might be unsurprising) and then degrades rapidly. Unexpectedly, such degradation is not caused by
# o...
#
#
# Answer: Based on the provided excerpts from the document, the following visual elements are present:
#
# 1. **Figures**:
#    - **Figure 9: Convolution in Depth** (Page 5)
#      - This figure likely illustrates the concept of convolution with regards to input, filter, and output dimensions, possibly showing diagrams of images and filters of various depths (e.g., grayscale: 10x10x1 and RGB: 10x10x3), and how convolution produces 2D outputs.
#    - **Figure 18: Residual Learning: A building block** (Page 14)
#      - This figure likely shows a block diagram of a residual learning unit as used in ResNet, illustrating the skip connection or shortcut paths that facilitate residual learning in deep neural networks.
#
# 2. **Possible Table or Diagram References**:
#    - Page 6 references "Stride and Padding" and "Zero-padding," which sometimes are supported by diagrams explaining how padding and stride affect convolution operations. However, no explicit figure is cited on this page.
#
# 3. **Section Headers as Visual Cues**:
#    - Section titles such as "Transfer Learning," "ResNet," and "Stride and Padding" may be styled visually for clarity and navigation.
#
# **Summary of Visual Elements Present:**
# - Diagrams or block figures about convolution dimensions and operations (Figure 9).
# - A block diagram about residual learning (Figure 18).
# - Section headers and possibly supporting illustrative elements related to stride, padding, and transfer learning.
#
# **If you need a detailed description of what these figures show,** here is a likely breakdown:
# - **Figure 9**: Shows the relationship between image depth and filter depth, and the result after applying convolution (2D feature maps).
# - **Figure 18**: Shows a neural network block with input, skip connection (identity), addition node, and ReLU/output—demonstrating the basic unit of residual learning.
#
# *Note: Actual images are not provided, but this is inferred from the context and captions in the supplied excerpts.*
# ======================================================================
